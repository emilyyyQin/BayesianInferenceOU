# %%
using GuidedProposals, DiffusionDefinition, ObservationSchemes
const GP = GuidedProposals
const DD = DiffusionDefinition
const OBS = ObservationSchemes

using StaticArrays, Random, Plots, LinearAlgebra
using Statistics

# seed used for this tutorial
Random.seed!(100)

## data generation ##
@diffusion_process FavettoSamsonModified{T,K} begin
    :dimensions
    process --> 2
    wiener --> 2

    :parameters
    (α, β, λ, μ, σ1, σ2) --> T
    dose --> K

    :additional
    diagdiff --> true
    constdiff --> true
end

DiffusionDefinition.b(t, x, P::FavettoSamsonModified) = @SVector [
    P.α * P.dose(t) - (P.λ +P.β)*x[1] + (P.μ-P.λ)*x[2],
    P.λ*x[1] - (P.μ-P.λ)*x[2]
]

DiffusionDefinition.σ(t, x, P::FavettoSamsonModified) = SDiagonal(P.σ1, P.σ2)
# Out:
# A new struct `FavettoSamsonModified{T, K}` has been defined.

# %%
θ = [116.7, 5.83, 1.25, 2.25, 2.0, 1.0]
P_target = FavettoSamsonModified(θ..., t->t/(1+t^2))
tt, y1 = 0.0:0.0001:10.0, @SVector [0.0, 0.0]
X = rand(P_target, tt, y1)

data = map(
    x->(x[1], x[2] + 7randn()),
    collect(zip(X.t, X.x))[1:1000:end]
)[2:end]

data1 = map(
    x->(x[1], x[2][1] + x[2][2] + 7randn()),
    collect(zip(X.t, X.x))[1:1000:end]
)[2:end]

data2 = map(
    x->(x[1], x[2][1] + randn()),
    collect(zip(X.t, X.x))[1:1000:end]
)[2:end]
# Out:
# 100-element Vector{Tuple{Float64, Float64}}:
#  (0.1, -0.4213782967167186)
#  (0.2, 0.145834831616247)
#  (0.3, 2.72780956857089)
#  (0.4, 2.3811872253780453)
#  (0.5, 5.470395496680982)
#  (0.6, 5.293457190897906)
#  (0.7, 7.9572180853515375)
#  (0.8, 8.74119446238982)
#  (0.9, 8.24489367367117)
#  (1.0, 9.510271271015897)
#  (1.1, 8.841895117346132)
#  (1.2, 8.975356390335522)
#  (1.3, 8.953581408349432)
#  ⋮
#  (8.9, 1.4869563327454869)
#  (9.0, 3.544116579412666)
#  (9.1, 1.0839016119643416)
#  (9.2, 1.358987662362617)
#  (9.3, 0.5162149813355459)
#  (9.4, 2.984261957369727)
#  (9.5, 3.2659808564424786)
#  (9.6, 2.081721761991482)
#  (9.7, 2.165358476382616)
#  (9.8, 2.5486679787749966)
#  (9.9, 1.3284671382653654)
#  (10.0, 3.228663031206581)

# %%
# let's examine the data
plot(X, Val(:vs_time), size=(800, 300))
scatter!(map(x->x[1], data), map(x->x[2][1], data), label="data")
savefig("simulated_data.png")

# %%
recording = (
    #P = FavettoSamsonModified([10, 5, #==# 0.0 #==#, 2, 1, 1]..., t-> 1/(1+t^2)),
    P = FavettoSamsonModified([116.7, 5.83, #==# 1.0 #==#, #==# 2.0 #==#, 2.0, 1.0]..., t->t/(1+t^2)), # diffusion law
    obs = load_data(
        ObsScheme(
            LinearGsnObs(
                0.0, (@SVector [0.0]); # dummy variables indicating datatype of observations
                L=(@SMatrix [1.0 1.0]), # observation operator
                Σ=(@SMatrix [7]) #1e-2*SDiagonal{2,Float64}(I) # noise on the observations
            )
        ),
        data1
    ),
    t0 = 0.0,
    x0_prior = KnownStartingPt(y1),
)
# Out:
# (P = FavettoSamsonModified{Float64, var"#13#14"}(116.7, 5.83, 1.0, 2.0, 2.0, 1.0, var"#13#14"()), obs = LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}[LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [5.012547309810912], 0.1, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [5.687127983464942], 0.2, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [-0.8746210577075479], 0.3, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [-0.22554419512768487], 0.4, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [12.621301966200146], 0.5, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [23.474194834922056], 0.6, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [5.21129650592069], 0.7, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [11.502038486758806], 0.8, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [16.004080160276168], 0.9, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [-0.4199624979450114], 1.0, false, Any[])  …  LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [0.47407847248631185], 9.1, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [1.9190640714349736], 9.2, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [4.232856865492089], 9.3, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [-8.657288791044298], 9.4, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [4.843084935881219], 9.5, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [6.867345468284206], 9.6, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [8.301786378423763], 9.7, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2}, SVector{1, Float64}, SMatrix{1, 1, Int64, 1}, Any}([1.0 1.0], [0.0], [7], [7.046542066049951], 9.8, false, Any[]), LinearGsnObs{0, 1, SVector{1, Float64}, NoFirstPassageTimes, SMatrix{1, 2, Float64, 2} ...

# %%
@diffusion_process FavettoSamsonAux{K,Q,R} begin
    :dimensions
    process --> 2
    wiener --> 2

    :parameters
    (α, β, λ, μ, σ1, σ2) --> K
    dose --> Q
    :auxiliary_info
    t0 --> Float64
    T --> Float64
    vT --> R

    :additional
    constdiff --> true
    linear --> true
end

DiffusionDefinition.B(t, P::FavettoSamsonAux) = @SMatrix [-(P.λ+ P.β) P.β; P.λ -P.μ]
DiffusionDefinition.β(t, P::FavettoSamsonAux) = @SVector [P.α* P.dose(t), 0.0]
DiffusionDefinition.σ(t, P::FavettoSamsonAux) = SDiagonal(P.σ1, P.σ2)

@load_diffusion FavettoSamsonAux
# Out:
# A new struct `FavettoSamsonAux{K, Q, R}` has been defined.

# %%
"""
Adaptive readjustment for the `i`th recording of the preconditioned
Crank–Nicolson scheme's memory parameter.
"""
max_p, min_p = 1e7, 1e-12
target_rate = 0.44
# define a time delay
offset = 9.6

function readjust(p_old, accpt_r, δ, mcmc_iter)
    p = sigmoid(logit(p_old)-(2*(accpt_r > target_rate)-1)* δ)
    p = max.(min.(p,  max_p), min_p)
end

sigmoid(x, a=1.0) = 1.0 / (1.0 + exp(-a*x))
logit(x, a=1.0) = (log(x) - log(1-x))/a

"""
    compute_δ(p, mcmc_iter)
δ decreases roughly proportional to scale/sqrt(iteration)
"""
function compute_δ(mcmc_iter)
    1.0 / sqrt(
        max(1.0, mcmc_iter/100 -offset)
    )
end
# Out:
# compute_δ

# %%
# define a transition kernel for θ
function customkernel(θ, s1::Symbol, s2::Symbol,scale=0.1)
	θ° = deepcopy(θ)
	θ°[s1] += 2.0*scale*(rand()-0.5)
    θ°[s2] += 2.0*scale*(rand()-0.5)
	θ°
end
# Out:
# customkernel (generic function with 2 methods)

# %%
function GaussianRandomWalk(Σ, pos=nothing)
    @assert size(Σ, 1) == size(Σ, 2)
    Σ = reshape(Σ, (size(Σ, 1), size(Σ, 2)))
     T = eltype(Σ)
    pos = (pos === nothing) ? fill(false, size(Σ, 1)) : pos
    new{T}(Symmetric(Σ), pos)
end
# Out:
# GaussianRandomWalk (generic function with 2 methods)

# %%
function simple_inference(AuxLaw, recording, dt, θ, s1::Symbol, s2::Symbol; ρ=0.5, q=0.2, num_steps=10^4)
	# initializations
	tts = OBS.setup_time_grids(recording, dt)
	PP = build_guid_prop(AuxLaw, recording, tts)
	PP° = deepcopy(PP)

	y1 = rand(recording.x0_prior) # just returns the starting point
	XX, WW, Wnr = rand(PP, y1)
	XX°, WW° = trajectory(PP)

	ll = loglikhd(PP, XX)
	paths = []
	θθ1 = Float64[θ[s1],]
    θθ2 = Float64[θ[s2],]
    θθ = Float64[θ[s1]/(θ[s2]-θ[s1]),]
#     θθ = Float64[θ[s1]/θ[s2],]
#     p_list = Float64[θ[s],]
#     p_mean = θ[s]
#     ssq = p_mean^2
	imp_a_r = 0
	param_a_r = 0

	# MCMC
	for i in 1:num_steps
		# impute a path
		_, ll° = rand!(PP, XX°, WW°, WW, ρ, Val(:ll), y1; Wnr=Wnr)

		if rand() < exp(ll°-ll)
			XX, WW, XX°, WW° = XX°, WW°, XX, WW
			ll = ll°
			imp_a_r += 1
		end

		# update parameter
        θ° = customkernel(θ, s1, s2, q)
		DD.set_parameters!(PP°, θ°)
		recompute_guiding_term!(PP°)
		_, ll° = GP.solve_and_ll!(XX°, WW, PP°, y1)

		if rand() < exp(ll°-ll) # uniform updates have no contribution to ll
			XX, PP, θ, XX°, PP°, θ° = XX°, PP°, θ°, XX, PP, θ
			ll = ll°
			param_a_r += 1
		end
		append!(θθ1, [θ[s1]])
        append!(θθ2, [θ[s2]])
        append!(θθ, [θ[s1]/(θ[s2]-θ[s1])])
#         append!(θθ, [θ[s1]/θ[s2]])
#         append!(p_list, [θ[s]])


		# progress message
		if i % 100 == 0
			println(
				"$i. ll=$ll, estimate=$(θ[s1]),$(θ[s2]), imp accpt rate: $(imp_a_r/100), ",
				"updt accpt rate: $(param_a_r/100)"
			)
            accpt_r = imp_a_r / 100
#             accpt_r = param_a_r/100
            δ = compute_δ(i)
            ρ = readjust(ρ, accpt_r, δ, i)
			imp_a_r = param_a_r = 0
            
            # now update transition kernel q
#             d = length(p_list)
#             p_mean = p_mean * d / (d+1) + θ[:λ] / (d+1)
#             ssq += θ[:λ]^2 / d
#             v = ssq - (d+1) / d * p_mean^2
#             q = 2.38^2 / d * v
#             p_list = []
            
		end

		# save intermediate path for plotting
		i % 400 == 0 && append!(paths, [deepcopy(XX)])
	end
	paths, θθ
end
# Out:
# simple_inference (generic function with 1 method)

# %%
# let's declare which parameters are not changing
DD.const_parameter_names(::Type{<:FavettoSamsonModified}) = (:α, :β,:σ1, :σ2) 
DD.const_parameter_names(::Type{<:FavettoSamsonAux}) = (:α, :β, :σ1, :σ2, :t0, :T, :vT, :xT)
# and do the inference
# paths, θθ= simple_inference(
# 	FavettoSamsonAux, recording, 0.02, Dict( :α=> 100.0, :β=> 2.0), :α, :β; ρ= 0.5, q=0.2, num_steps= 10^4
# ) 
paths, θθ= simple_inference(
	FavettoSamsonAux, recording, 0.02, Dict( :λ=> 1.0, :μ=> 2.0), :λ, :μ; ρ= 0.5, q=0.2, num_steps= 10^4
)
# Out:
# 100. ll=-494.2765358059844, estimate=1.588775233539613,3.086900363485949, imp accpt rate: 0.15, updt accpt rate: 0.44
# 200. ll=-487.2330969316569, estimate=1.2489958841561322,2.1792209748269613, imp accpt rate: 0.15, updt accpt rate: 0.41
# 300. ll=-486.6993291793727, estimate=1.4143460263697154,2.58391294098655, imp accpt rate: 0.43, updt accpt rate: 0.46
# 400. ll=-483.65063374828776, estimate=1.5251818716793242,2.9281909170606943, imp accpt rate: 0.52, updt accpt rate: 0.45
# 500. ll=-482.592554599025, estimate=1.1580703775022367,2.126619156651892, imp accpt rate: 0.24, updt accpt rate: 0.51
# 600. ll=-480.93771621991095, estimate=1.0125388452467843,1.851487453327079, imp accpt rate: 0.34, updt accpt rate: 0.34
# 700. ll=-480.7324072578739, estimate=1.191203031561055,2.2446026924221427, imp accpt rate: 0.61, updt accpt rate: 0.34
# 800. ll=-486.5645586391388, estimate=1.5405001528992746,2.86175712186069, imp accpt rate: 0.47, updt accpt rate: 0.49
# 900. ll=-491.75081353876413, estimate=1.4507664437144587,2.771592712620279, imp accpt rate: 0.52, updt accpt rate: 0.35
# 1000. ll=-487.5544970918885, estimate=1.6167924584440938,2.9838119652857396, imp accpt rate: 0.35, updt accpt rate: 0.36
# 1100. ll=-493.9997797114855, estimate=1.0341706536067845,2.0840951782482917, imp accpt rate: 0.24, updt accpt rate: 0.35
# 1200. ll=-487.861674456978, estimate=1.5378520797926283,2.837679167125493, imp accpt rate: 0.57, updt accpt rate: 0.34
# 1300. ll=-495.2577116189947, estimate=1.565668232475311,3.14064876552664, imp accpt rate: 0.56, updt accpt rate: 0.49
# 1400. ll=-495.24402029875796, estimate=1.8896583775155906,3.415773206358683, imp accpt rate: 0.76, updt accpt rate: 0.51
# 1500. ll=-492.86642325617436, estimate=1.953372799235998,3.6908782773406275, imp accpt rate: 0.81, updt accpt rate: 0.5
# 1600. ll=-493.30687334880827, estimate=1.8919678010767416,3.5390496893343144, imp accpt rate: 0.67, updt accpt rate: 0.44
# 1700. ll=-491.6367568527408, estimate=1.3433601246083293,2.4963155696944654, imp accpt rate: 0.4, updt accpt rate: 0.48
# 1800. ll=-486.57282461932635, estimate=1.4199883542058567,2.618892725140917, imp accpt rate: 0.07, updt accpt rate: 0.45
# 1900. ll=-493.80234392682524, estimate=1.4374105399763595,2.8046682596456325, imp accpt rate: 0.35, updt accpt rate: 0.36
# 2000. ll=-494.24838321578864, estimate=1.8216588722943345,3.4784210704623644, imp accpt rate: 0.74, updt accpt rate: 0.51
# 2100. ll=-485.7871927991256, estimate=1.2691864500683512,2.3527095131961118, imp accpt rate: 0.33, updt accpt rate: 0.49
# 2200. ll=-491.6130936940007, estimate=1.703404418492767,3.2838345725341966, imp accpt rate: 0.51, updt accpt rate: 0.42
# 2300. ll=-493.90743031809166, estimate=1.4709079068857513,2.973721895594801, imp accpt rate: 0.77, updt accpt rate: 0.47
# 2400. ll=-487.4883865805145, estimate=1.3561859395944984,2.5426133770424304, imp accpt rate: 0.17, updt accpt rate: 0.37
# 2500. ll=-485.4449100155387, estimate=1.1301521300388058,2.1807408241373336, imp accpt rate: 0.11, updt accpt rate: 0.47
# 2600. ll=-487.04714064635397, estimate=1.2765195929577364,2.4846928850912193, imp accpt rate: 0.21, updt accpt rate: 0.29
# 2700. ll=-493.42170678656504, estimate=2.150945432690988,4.044423058267262, imp accpt rate: 0.49, updt accpt rate: 0.5
# 2800. ll=-491.2143648969112, estimate=1.8159862521713264,3.431813476553119, imp accpt rate: 0.66, updt accpt rate: 0.52
# 2900. ll=-492.6976960518166, estimate=1.7714465425454629,3.1724373123196057, imp accpt rate: 0.68, updt accpt rate: 0.44
# 3000. ll=-492.6014805397827, estimate=1.609540158160379,3.0426187789777934, imp accpt rate: 0.45, updt accpt rate: 0.48
# 3100. ll=-489.4362309399749, estimate=1.3324379916739708,2.606974094541109, imp accpt rate: 0.23, updt accpt rate: 0.42
# 3200. ll=-490.92434304924717, estimate=1.508330883729198,2.8816355741965385, imp accpt rate: 0.19, updt accpt rate: 0.42
# 3300. ll=-496.09187430035365, estimate=2.2499140984035013,4.400705089313259, imp accpt rate: 0.54, updt accpt rate: 0.57
# 3400. ll=-495.95475581819653, estimate=1.8028448182781658,3.6112599538468872, imp accpt rate: 0.81, updt accpt rate: 0.45
# 3500. ll=-494.5949130804362, estimate=2.0902263751170884,4.00751203069021, imp accpt rate: 0.83, updt accpt rate: 0.5
# 3600. ll=-494.35242406491295, estimate=2.085211552928192,3.7892610715462958, imp accpt rate: 0.78, updt accpt rate: 0.43
# 3700. ll=-490.2702345450733, estimate=2.566578368077102,4.636653531022921, imp accpt rate: 0.6, updt accpt rate: 0.52
# 3800. ll=-494.4459872412075, estimate=2.806306246292874,4.922421216276291, imp accpt rate: 0.4, updt accpt rate: 0.52
# 3900. ll=-496.2620526811559, estimate=1.9085371778794151,3.879329609738068, imp accpt rate: 0.59, updt accpt rate: 0.59
# 4000. ll=-491.91455383226685, estimate=1.847922189552825,3.452380899090217, imp accpt rate: 0.71, updt accpt rate: 0.44
# 4100. ll=-493.8805041123636, estimate=2.0075672538494707,3.6631400477772478, imp accpt rate: 0.55, updt accpt rate: 0.59
# 4200. ll=-493.2376214866173, estimate=1.9914911114603608,3.6951349711681236, imp accpt rate: 0.84, updt accpt rate: 0.54
# 4300. ll=-494.0536640782999, estimate=2.021712029122279,3.6660330812778144, imp accpt rate: 0.52, updt accpt rate: 0.44
# 4400. ll=-496.9110385417419, estimate=2.561946508561654,4.359808323762628, imp accpt rate: 0.7, updt accpt rate: 0.5
# 4500. ll=-496.10556822653325, estimate=2.361071873852478,4.392368958997819, imp accpt rate: 0.55, updt accpt rate: 0.6
# 4600. ll=-494.31890774727196, estimate=2.4537839652077387,4.592081623544252, imp accpt rate: 0.46, updt accpt rate: 0.63
# 4700. ll=-492.77913552818546, estimate=2.4419505546822733,4.492534648456072, imp accpt rate: 0.43, updt accpt rate: 0.58
# 4800. ll=-492.85548655419734, estimate=2.5892876763873103,4.607157953038329, imp accpt rate: 0.26, updt accpt rate: 0.47
# 4900. ll=-493.08634004737536, estimate=2.4587463723531995,4.516020515856302, imp accpt rate: 0.43, updt accpt rate: 0.58
# 5000. ll=-492.88818024626437, estimate=2.4371205437965453,4.443882506475717, imp accpt rate: 0.33, updt accpt rate: 0.52
# 5100. ll=-489.5585329949541, estimate=2.7705032907888554,4.927552972579428, imp accpt rate: 0.35, updt accpt rate: 0.45
# 5200. ll=-489.2915646331202, estimate=2.994236536682482,5.586492273936927, imp accpt rate: 0.1, updt accpt rate: 0.6
# 5300. ll=-488.65443600347794, estimate=3.3501630918015834,5.970549112983452, imp accpt rate: 0.05, updt accpt rate: 0.58
# 5400. ll=-490.5564533813056, estimate=3.0642346879999685,5.829220050257504, imp accpt rate: 0.14, updt accpt rate: 0.55
# 5500. ll=-489.48033598050745, estimate=3.2951288871854767,6.070047215943596, imp accpt rate: 0.17, updt accpt rate: 0.65
# 5600. ll=-493.225013561719, estimate=2.6509364875475256,4.7753961498217325, imp accpt rate: 0.43, updt accpt rate: 0.57
# 5700. ll=-492.7332684613244, estimate=2.5602940814767425,4.552965899944163, imp accpt rate: 0.32, updt accpt rate: 0.5
# 5800. ll=-492.0256400070869, estimate=3.0862037088515324,5.563422917072046, imp accpt rate: 0.44, updt accpt rate: 0.62
# 5900. ll=-491.9600476045979, estimate=2.8466689607848132,5.548760362741817, imp accpt rate: 0.33, updt accpt rate: 0.53
# 6000. ll=-491.9467280167266, estimate=2.9789759506864897,5.624627332840269, imp accpt rate: 0.37, updt accpt rate: 0.61
# 6100. ll=-488.33161020512404, estimate=2.8433783849828616,5.333102864340007, imp accpt rate: 0.3, updt accpt rate: 0.6
# 6200. ll=-491.48165218779457, estimate=2.5839762313883234,4.688886390625305, imp accpt rate: 0.68, updt accpt rate: 0.61
# 6300. ll=-492.3872346836232, estimate=3.0282425932806594,5.764280371367452, imp accpt rate: 0.52, updt accpt rate: 0.63
# 6400. ll=-493.91609160931785, estimate=2.8233134359120666,5.484106986395784, imp accpt rate: 0.39, updt accpt rate: 0.58
# 6500. ll=-494.1082958574352, estimate=3.0795795842889646,6.003827611275866, imp accpt rate: 0.5, updt accpt rate: 0.59
# 6600. ll=-492.78711935511626, estimate=2.6216636078188933,4.829748655520369, imp accpt rate: 0.35, updt accpt rate: 0.62
# 6700. ll=-494.6143827909602, estimate=3.390372321432353,6.2537021187337825, imp accpt rate: 0.44, updt accpt rate: 0.65
# 6800. ll=-496.96194907605695, estimate=2.6358517815405222,5.307568682332646, imp accpt rate: 0.59, updt accpt rate: 0.65
# 6900. ll=-492.6154542764913, estimate=2.6937706189694297,5.08015090912222, imp accpt rate: 0.42, updt accpt rate: 0.61
# 7000. ll=-486.34499469972087, estimate=3.2847580450235534,5.969694828526112, imp accpt rate: 0.36, updt accpt rate: 0.63
# 7100. ll=-488.85285500231475, estimate=3.6827615527873507,6.879342799057789, imp accpt rate: 0.14, updt accpt rate: 0.57
# 7200. ll=-489.59136250378396, estimate=3.9164941603601093,7.116719839422549, imp accpt rate: 0.18, updt accpt rate: 0.64
# 7300. ll=-492.4332661420035, estimate=3.659716611223151,6.960303977377608, imp accpt rate: 0.4, updt accpt rate: 0.6
# 7400. ll=-486.7382753360014, estimate=3.7305456750353434,6.496700051125186, imp accpt rate: 0.36, updt accpt rate: 0.66
# 7500. ll=-490.9218512285138, estimate=3.4721415016757193,6.417876319993739, imp accpt rate: 0.45, updt accpt rate: 0.56
# 7600. ll=-485.9498983272443, estimate=3.6384204869245726,6.553455618057153, imp accpt rate: 0.42, updt accpt rate: 0.64
# 7700. ll=-485.9667036282525, estimate=3.7000498118210543,6.969027724747766, imp accpt rate: 0.33, updt accpt rate: 0.68
# 7800. ll=-490.9278649429684, estimate=3.372391182121056,6.164985887958538, imp accpt rate: 0.48, updt accpt rate: 0.61
# 7900. ll=-487.2296725283547, estimate=3.6115330329690893,6.662945832891291, imp accpt rate: 0.37, updt accpt rate: 0.61
# 8000. ll=-494.1182429785071, estimate=3.1094699274162245,6.07160239010479, imp accpt rate: 0.47, updt accpt rate: 0.59
# 8100. ll=-491.7808087854719, estimate=3.699803925612545,6.30375288633808, imp accpt rate: 0.45, updt accpt rate: 0.57
# 8200. ll=-488.6805877205644, estimate=3.48789437007718,6.528063369905558, imp accpt rate: 0.42, updt accpt rate: 0.61
# 8300. ll=-490.09014812568364, estimate=3.5401184107915875,6.609443702920021, imp accpt rate: 0.28, updt accpt rate: 0.58
# 8400. ll=-492.7173363012617, estimate=3.4468803421805188,6.396017897708476, imp accpt rate: 0.37, updt accpt rate: 0.62
# 8500. ll=-492.38531017775466, estimate=3.1765590934429797,5.771344935828669, imp accpt rate: 0.48, updt accpt rate: 0.58
# 8600. ll=-491.2131031360501, estimate=3.1749988273810312,5.941442079397559, imp accpt rate: 0.44, updt accpt rate: 0.7
# 8700. ll=-484.1347401489607, estimate=3.71589801346823,7.0488024069722695, imp accpt rate: 0.46, updt accpt rate: 0.65
# 8800. ll=-494.44598894159327, estimate=4.075234923700235,7.8231287835960766, imp accpt rate: 0.36, updt accpt rate: 0.62
# 8900. ll=-492.0010440638844, estimate=4.521092337014234,8.43690595138801, imp accpt rate: 0.41, updt accpt rate: 0.66
# 9000. ll=-484.8814070684985, estimate=4.601075809235171,8.608899111304517, imp accpt rate: 0.39, updt accpt rate: 0.68
# 9100. ll=-487.2795308149213, estimate=5.012320816739912,9.13237580464913, imp accpt rate: 0.39, updt accpt rate: 0.73
# 9200. ll=-481.33083254733464, estimate=4.999661923006592,9.046995706862303, imp accpt rate: 0.38, updt accpt rate: 0.73
# 9300. ll=-483.8093056914901, estimate=4.935065513262485,9.234698528226296, imp accpt rate: 0.41, updt accpt rate: 0.66
# 9400. ll=-489.00505653142096, estimate=4.768899074742835,8.567701817703947, imp accpt rate: 0.48, updt accpt rate: 0.65
# 9500. ll=-481.6634790400757, estimate=4.663314322922088,8.409250648935156, imp accpt rate: 0.42, updt accpt rate: 0.61
# 9600. ll=-487.99516850244294, estimate=4.884610073732597,8.928261900326145, imp accpt rate: 0.39, updt accpt rate: 0.63
# 9700. ll=-478.489111610285, estimate=4.958549999086188,8.662463228330502, imp accpt rate: 0.42, updt accpt rate: 0.65
# 9800. ll=-482.72501026417564, estimate=4.470455160384743,7.781438437035634, imp accpt rate: 0.42, updt accpt rate: 0.64
# 9900. ll=-492.00149895470787, estimate=4.215213087361844,7.858425376275199, imp accpt rate: 0.45, updt accpt rate: 0.56
# 10000. ll=-484.10615437861713, estimate=4.636658503358491,8.421544744028308, imp accpt rate: 0.44, updt accpt rate: 0.57
# (Any[Trajectory{Vector{Float64}, Vector{SVector{2, Float64}}}[Trajectory{Vector{Float64}, Vector{SVector{2, Float64}}}([0.0, 0.02, 0.04, 0.06, 0.08, 0.1], SVector{2, Float64}[[0.0, 0.0], [0.06410788524980754, -0.15246994958401072], [0.002937309178103753, -0.3828675894686211], [0.2562842254667784, -0.6456178253459037], [0.7473171601542855, -0.6060857658909997], [1.1292448068151655, -0.6040289569080897]]), Trajectory{Vector{Float64}, Vector{SVector{2, Float64}}}([0.1, 0.12, 0.14, 0.16, 0.18, 0.2], SVector{2, Float64}[[1.1292448068151655, -0.6040289569080897], [1.5653662079592485, -0.5309882396531035], [1.3972007581054287, -0.4311263331435849], [1.8923051140701608, -0.5316507269695947], [1.6350579386777966, -0.5339934509625102], [1.578257433976265, -0.3078181478965511]]), Trajectory{Vector{Float64}, Vector{SVector{2, Float64}}}([0.2, 0.22, 0.24, 0.26, 0.28, 0.3], SVector{2, Float64}[[1.578257433976265, -0.3078181478965511], [1.5119696654231634, -0.24609332767635894], [1.7757005545828828, -0.32290196584014835], [1.9562106798547547, -0.30528758927609856], [2.2052602877942764, -0.2001910799582492], [2.6772658930059867, -0.047680807927602833]]), Trajectory{Vector{Float64}, Vector{SVector{2, Float64}}}([0.3, 0.32, 0.34, 0.36, 0.38, 0.4], SVector{2, Float64}[[2.6772658930059867, -0.047680807927602833], [2.799111508667442, 0.15358497802005644], [3.230491825193447, 0.25789875181315913], [3.8799526730004454, 0.4382408200371024], [3.8088205858379642, 0.6254206761385841], [3.9059039210824236, 0.5744203930509788]]), Trajectory{Vector{Float64}, Vector{SVector{2, Float64}}}([0.4, 0.42, 0.44, 0.46, 0.48, 0.5], SVector{2, Float64}[[3.9059039210824236, 0.5744203930509788], [4.576600668901975, 0.7365942420315553], [4.361607106268206, 1.0020438656638893], [4.656410384928047, 1.309867541613403], [4.975676182124616, 1.4340098597185524], [5.362712854790788, 1.5970912907498374]]), Trajectory{Vector{Float64}, Vector{SVector{2, Float64}}}([0.5, 0.52, 0.54, 0.56, 0.58, 0.6], SVector{2, Float64}[[5.362712854790788, 1.5970912907498374], [4.855968535691421, 1.8604977645066862], [5.004098558242479, 1.8234538694985123], [5.409866986057763, 1.910893497780561], [5.857829036287098, 1.9159859697690342], [6.165365272761481, 2.0232273527436986]]), Trajectory{Vector{Float64}, Vector{SVector{2, Float64}}}([0.6, 0.62, 0.64, 0.66, 0.68, 0.7], SVector{2, Float64}[[6.165365272761481, 2.0232273527436986], [6.365344084161055, 2.2813370264013444], [6.436570163772196, 2.5077280354180638], [6.088356505950883, 2.353201002230087], [6.133770787626925, 2.4957273494452723], [5.9660219133501835, 2.72889332656303]]), Trajectory{Vector{Float64}, Vector{SVector{2, Float64}}}([0.7, 0.72, 0.74, 0.76, 0.78, 0.8], SVector{2, Float64}[[5.9660219133501835, 2.72889332656303], [6.760920911888815, 3.2472309343490053], [6.616563036857309, 3.096172021575418], [7.491974809528183, 3.2803225303180663], [7.295855991976431, 3.429256042000374], [6.76176218966096, 3.6435357724812567]]), Trajectory{Vector{Float64}, Vector{SVector{2, Float64}}}([0.8, 0.82, 0.84, 0.86, 0.88, 0.9], SVector{2, Float64}[[6.76176218966096, 3.6435357724812567], [6.8651297690227, 3.768106372445405], [7.080649898937498, 3.797670892586735], [7.662661093586043, 3.8863861968744726], [8.240829279430738, 3.9655252778296908], [8.463637023257913, 4.158828255793075]]), Trajectory{Vector{Float64}, Vector{SVector{2, Float64}}}([0.9, 0.92, 0.94, 0.96, 0.98, 1.0], SVector{2, Float64}[[8.463637023257913, 4.158828255793075], [8.293486740231243, 4.4959712699016245], [7.967188714679793, 4.524596522363514], [8.452137959092324, 4.443324778474962], [8.82843613376401, 4.803956479202148], [9.227643909177061, 5.073458951838464]])  …  Trajectory{Vector{Float64}, Vector{SVector{2, Float64}}}([9.0, 9.02, 9.04, 9.06, 9.08, 9.1], SVector{2, Float64}[[1.4769822945083637, 2.6808279384370373], [1.4962512678158277, 2.4377131969276675], [1.4946154919315189, 2.3414053198226235], [1.2888385783356593, 2.2880505139199707], [1.8867306634142966, 2.3758399448238388],  ...

# %%
p1 = plot(θθ, title = "θ=[116.7, 5.83, 1.25, 2.25, 2.0, 1.0]",label="")
plot!(θθ-> 1.25,label="")
display(p1)
savefig("infer_λ_μ_ratio.png")
